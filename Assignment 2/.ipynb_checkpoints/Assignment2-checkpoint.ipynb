# %% [markdown]
# # Social Media Analytics
# ## Group Assignment #2
# ### Group Members: Anurag Chilukuri, Brooks Beckelman,       J Dallas Griffin, Lindsay Tober, Nicole Eric
# ---
#
# ## Part 1: Find Predictors of Influence

# %%
import pandas as pd

data = pd.read_csv('train.csv')
pd.set_option('display.max_columns', 100)

# Display first row of data
data.iloc[0]
# Out:
# Choice                     0.000000
# A_follower_count         228.000000
# A_following_count        302.000000
# A_listed_count             3.000000
# A_mentions_received        0.583979
# A_retweets_received        0.100503
# A_mentions_sent            0.100503
# A_retweets_sent            0.100503
# A_posts                    0.362150
# A_network_feature_1        2.000000
# A_network_feature_2      166.500000
# A_network_feature_3    11355.000000
# B_follower_count       34463.000000
# B_following_count      29808.000000
# B_listed_count          1689.000000
# B_mentions_received       15.430498
# B_retweets_received        3.984029
# B_mentions_sent            8.204331
# B_retweets_sent            0.332423
# B_posts                    6.988815
# B_network_feature_1       66.000000
# B_network_feature_2       75.530303
# B_network_feature_3     1916.893939
# Name: 0, dtype: float64

# %%
# Get summary statistics on dataset
data.describe()
# Out:
#             Choice  A_follower_count  A_following_count  A_listed_count  \
# count  5500.000000      5.500000e+03       5.500000e+03     5500.000000
# mean      0.509455      6.498840e+05       1.265895e+04     5952.453273
# std       0.499956      2.028787e+06       4.900867e+04    17339.141191
# min       0.000000      1.600000e+01       0.000000e+00        0.000000
# 25%       0.000000      2.663750e+03       3.220000e+02       85.000000
# 50%       1.000000      4.558900e+04       7.780000e+02      932.000000
# 75%       1.000000      3.927380e+05       2.838000e+03     6734.000000
# max       1.000000      3.654319e+07       1.165830e+06   549144.000000
#
#        A_mentions_received  A_retweets_received  A_mentions_sent  \
# count         5.500000e+03          5500.000000      5500.000000
# mean          2.666032e+03          1032.371839         6.011873
# std           2.916543e+04         10954.953223         9.519797
# ...

# %% [markdown]
# ## Part 2: Find Influencers from Twitter
