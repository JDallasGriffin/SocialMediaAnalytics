# %%
from nltk import word_tokenize

def get_targets(post, brand_dict):
    
    ''' Take individual post and return only the words that appear in the brand dictionary (brands and models) '''
    
    # Tokenize post
    tokens = word_tokenize(post)
    
    # Remove all tokens but brands and models
    targets = [word.lower() for word in tokens if word.lower() in brand_dict.keys() or word.lower() in brand_dict.values()]
    
    return targets



def models_to_brands(targets, brand_dict):
    
    ''' Take list of brands and models and return new list where the models are converted to their respective brands '''
    
    # Create list to store brand names
    brands = []
    
    # Iterate through words
    for word in targets:
        
        # Convert models to brands and add to brand list
        if word in brand_dict.keys():
            brands.append(brand_dict[word])
            
        # Add brands that were mentioned to list
        elif word in brand_dict.values():
            brands.append(word)
        
        else:
            continue
        
    return brands



def get_unique_brands(brand_list):
    
    ''' Take list of brands and return new list that removes duplicates '''
    
    # Create list to store unique brand names
    unique_brands = []
    
    for brand in brand_list:
        if brand not in unique_brands:
            unique_brands.append(brand)
    
    return unique_brands

# %%
import pandas as pd

edmunds = pd.read_csv('Edmunds_Posts.csv')
posts = edmunds['Post'].dropna().tolist()
test = posts[0:100]

# %%
cars = pd.read_csv('cars.csv')

makes = cars['make']
models = cars['model']

# Convert make and model strings to unicode
keys = []
values = []
for model in models:
    keys.append(unicode(model, "ISO-8859-1"))

for make in makes:
    values.append(unicode(make, "ISO-8859-1"))
    

# Create dictionary mapping models to their respective brands
brand_dict = dict(zip(keys, values))

# %%
brand_dict
# Out:
# {u'128i': u'bmw',
#  u'3-series': u'bmw',
#  u'300M': u'chrysler',
#  u'328i': u'bmw',
#  u'330c': u'bmw',
#  u'330ci': u'bmw',
#  u'335d': u'bmw',
#  u'335i': u'bmw',
#  u'370z': u'nissan',
#  u'3er': u'bmw',
#  u'4-series': u'bmw',
#  u'4Runner': u'toyota',
#  u'5-series': u'bmw',
#  u'528i': u'bmw',
#  u'535i': u'bmw',
#  u'5DR': u'honda',
#  u'5er': u'bmw',
#  u'6-series': u'bmw',
#  u'640i': u'bmw',
#  u'6i': u'mazda',
#  u'6mt': u'infiniti',
#  u'APV': u'suzuki',
#  u'AZ-Offroad': u'mazda',
#  u'AZ-Wagon': u'mazda',
#  u'Accent': u'hyundai',
#  u'Acty': u'honda',
#  u'Aerio': u'suzuki',
#  u'Agile': u'chevrolet',
#  u'Allion': u'toyota',
#  u'Alphard': u'toyota',
#  u'Amaze': u'honda',
#  u'Aria': u'honda',
#  u'Atenza': u'mazda',
#  u'Atos': u'hyundai',
#  u'Atoz': u'hyundai',
#  u'Aurion': u'toyota',
#  u'Auris': u'toyota',
#  u'Avalon': u'toyota',
#  u'Avante': u'hyundai',
#  u'Avanza': u'toyota',
#  u'Avensis': u'toyota',
#  u'Aveo': u'chevrolet',
#  u'Axela': u'mazda',
#  u'Axio': u'toyota',
#  u'Aygo': u'toyota',
#  u'BRZ': u'subaru',
#  u'BT-50': u'mazda',
#  u'Belta': u'toyota',
#  u'Biante': u'mazda',
#  u'Bongo': u'mazda',
#  u'Brio': u'honda',
#  u'CR-V': u'honda',
#  u'CR-Z': u'honda',
#  u'CX-5': u'mazda',
#  u'CX-7': u'mazda',
#  u'CX-9': u'mazda',
#  u'Camaro': u'chevrolet',
#  u'Cami': u'toyota',
#  u'Camry': u'toyota',
#  u'Cappuccino': u'suzuki',
#  u'Caprice': u'chevrolet',
#  u'Captiva': u'chevrolet',
#  u'Carol': u'mazda',
#  u'Carri': u'toyota',
#  u'Celta': u'chevrolet',
#  u'Centennial': u'hyundai',
#  u'Century': u'toyota',
#  u'Cervo': u'suzuki',
#  u'City': u'honda',
#  u'Civic': u'honda',
#  u'Click': u'hyundai',
#  u'Coaster': u'toyota',
#  u'Cobalt': u'chevrolet',
#  u'Colorado': u'chevrolet',
#  u'Comfort': u'toyota',
#  u'Condor': u'toyota',
#  u'Corolla/Sprinter': u'toyota',
#  u'Corvette': u'chevrolet',
#  u'Crider': u'honda',
#  u'Crosstour': u'honda',
#  u'Crown\xa0Victoria': u'ford',
#  u'Cruze': u'chevrolet',
#  u'Demio': u'mazda',
#  u'Dex': u'subaru',
#  u'Dyna': u'toyota',
#  u'Dynasty': u'hyundai',
#  u'Echo': u'toyota',
#  u'Elantra': u'hyundai',
#  u'Equator': u'suzuki',
#  u'Equinox': u'chevrolet',
#  u'Equus': u'hyundai',
#  u'Ertiga': u'suzuki',
#  u'Esteem': u'suzuki',
#  u'Estima': u'toyota',
#  u'Etios': u'toyota',
#  u'Every Landy': u'suzuki',
#  u'Excel,': u'hyundai,',
#  u'Excel.': u'hyundai.',
#  u'Exiga': u'subaru',
#  u'Express': u'chevrolet',
#  u'FCX': u'honda',
#  u'FJ Cruiser': u'toyota',
#  u'Familia': u'mazda',
#  u'Fiedler': u'toyota',
#  u'Fiesta': u'ford',
#  u'Focus': u'ford',
#  u'Forester': u'subaru',
#  u'Fortuner': u'toyota',
#  u'Freed': u'honda',
#  u'Fronte': u'suzuki',
#  u'Fusion': u'ford',
#  u'G6': u'pontiac',
#  u'Genesis': u'hyundai',
#  u'Getz': u'hyundai',
#  u'Grand Blazer': u'chevrolet',
#  u'Grandeur': u'hyundai',
#  u'Granvia': u'toyota',
#  u'HiClass': u'toyota',
#  u'Hiace': u'toyota',
#  u'Highlander': u'toyota',
#  u'Hilux': u'toyota',
#  u'Hilux Surf': u'toyota',
#  u'Hobio': u'honda',
#  u'ILX': u'acura',
#  u'Ignis': u'suzuki',
#  u'Impala': u'chevrolet',
#  u'Impreza': u'subaru',
#  u'Impreza XV': u'subaru',
#  u'Innova': u'toyota',
#  u'Insight': u'honda',
#  u'Inspire': u'honda',
#  u'Isis': u'toyota',
#  u'Jade': u'honda',
#  u'Jazz': u'honda',
#  u'Jimny': u'suzuki',
#  u'Kijang': u'toyota',
#  u'Kingdom': u'toyota',
#  u'Kizashi': u'suzuki',
#  u'Kluger': u'toyota',
#  u'Lacetti': u'chevrolet',
#  u'Land Cruiser': u'toyota',
#  u'Landy': u'suzuki',
#  u'Lanos': u'chevrolet',
#  u'Lantra': u'hyundai',
#  u'Lapin': u'suzuki',
#  u'Lavity': u'hyundai',
#  u'Legacy': u'subaru',
#  u'Legend': u'honda',
#  u'LiteAce': u'toyota',
#  u'Lova': u'chevrolet',
#  u'Lumina': u'chevrolet',
#  u'M3': u'bmw',
#  u'M5': u'bmw',
#  u'M6': u'bmw',
#  u'MDX': u'acura',
#  u'MR Wagon': u'suzuki',
#  u'MX-5': u'mazda',
#  u'Majesta': u'toyota',
#  u'Malibu': u'chevrolet',
#  u'Mark X': u'toyota',
#  u'Matrix': u'toyota',
#  u'Mazda2': u'mazda',
#  u'Mazda3': u'mazda',
#  u'Mazda5': u'mazda',
#  u'Mazda6': u'mazda',
#  u'Mazda8': u'mazda',
#  u'Mighty Boy': u'suzuki',
#  u'MiniAce': u'toyota',
#  u'Mobilio': u'honda',
#  u'Montana': u'chevrolet',
#  u'N-Box': u'honda',
#  u'N-One': u'honda',
#  u'N-WGN': u'honda',
#  u'N200': u'chevrolet',
#  u'NSX': u'honda',
#  u'Nadia': u'toyota',
#  u'Niva': u'chevrolet',
#  u'Noah': u'toyota',
#  u'Odyssey': u'honda',
#  u'Omega': u'chevrolet',
#  u'Onix': u'chevrolet',
#  u'Optra': u'chevrolet',
#  u'Orlando': u'chevrolet',
#  u'Outback': u'subaru',
#  u'Outback Sport': u'subaru',
#  u'Palette': u'suzuki',
#  u'Passo': u'toyota',
#  u'Picnic': u'toyota',
#  u'Pilot': u'honda',
#  u'Platz': u'toyota',
#  u'Pleo': u'subaru',
#  u'Pony': u'hyundai',
#  u'Porte': u'toyota',
#  u'Prelude': u'honda',
#  u'Premacy': u'mazda',
#  u'Premio': u'toyota',
#  u'Prisma': u'chevrolet',
#  u'Prius': u'toyota',
#  u'Probox': u'toyota',
#  u'Qualis': u'toyota',
#  u'R1': u'subaru',
#  u'R2': u'subaru',
#  u'RAV4': u'toyota',
#  u'RDX': u'acura',
#  u'RSX': u'acura',
#  u'RX-8': u'mazda',
#  u'Ractis': u'toyota',
#  u'Raum': u'toyota',
#  u'Reiz': u'toyota',
#  u'Ridgeline': u'honda',
#  u'Rumion': u'toyota',
#  u'S-10': u'chevrolet',
#  u'SX4': u'suzuki',
#  u'Sai': u'toyota',
#  u'Sail': u'chevrolet',
#  u'Sambar': u'subaru',
#  u'Santamo': u'hyundai',
#  u'Santro': u'hyundai',
#  u'Scepter': u'toyota',
#  u'Scoupe': u'hyundai',
#  u'Scrum': u'mazda',
#  u'Sequoia': u'toyota',
#  u'Shuttle': u'honda',
#  u'Sienna': u'toyota',
#  u'Sienta': u'toyota',
#  u'Silverado': u'chevrolet',
#  u'Sofia': u'toyota',
#  u'Solio': u'suzuki',
#  u'Sonata': u'hyundai',
#  u'Sonic': u'chevrolet',
#  u'Spark': u'chevrolet',
#  u'Sparky': u'toyota',
#  u'Spike': u'honda',
#  u'Spirior': u'honda',
#  u'Splash': u'suzuki',
#  u'Stallion': u'toyota',
#  u'Stella': u'subaru',
#  u'Stellar': u'hyundai',
#  u'StepWGN': u'honda',
#  u'Stream': u'honda',
#  u'Streamliner': u'pontiac',
#  u'Suburban': u'chevrolet',
#  u'Succeed': u'toyota',
#  u'Swift': u'suzuki',
#  u'TSX': u'acura',
#  u'Tacoma': u'toyota',
#  u'Tahoe': u'chevrolet',
#  u'Tamaraw': u'toyota',
#  u'Tarago': u'toyota',
#  u'Taurus': u'ford',
#  u'Tavera': u'chevrolet',
#  u'Tiara': u'toyota',
#  u'Tiburon': u'hyundai',
#  u'Tornado': u'chevrolet',
#  u'Torpedo': u'pontiac',
#  u'Tourneo': u'ford',
#  u'TownAce': u'toyota',
#  u'ToyoAce': u'toyota',
#  u'Tracker': u'chevrolet',
#  u'TrailBlazer': u'chevrolet',
#  u'Traverse': u'chevrolet',
#  u'Tundra': u'toyota',
#  u'Tuscani': u'hyundai',
#  u'Uplander': u'chevrolet',
#  u'Urban Cruiser': u'toyota',
#  u'Vamos': u'honda',
#  u'Vanguard': u'toyota',
#  u'Veloster': u'hyundai',
#  u'Venture': u'toyota',
#  u'Venza': u'toyota',
#  u'Verna': u'hyundai',
#  u'Verso': u'toyota',
#  u'Vezel': u'honda',
#  u'Vibe': u'pontiac',
#  u'Vienta': u'toyota',
#  u'Vios': u'toyota',
#  u'Vitz': u'toyota',
#  u'Volt': u'chevrolet',
#  u'Voxy': u'toyota',
#  u'Wagon R': u'suzuki',
#  u'Wave': u'pontiac',
#  u'X-90': u'suzuki',
#  u'XL7\xa0': u'suzuki',
#  u'Xcent': u'hyundai',
#  u'Yaris': u'toyota',
#  u'ZEST': u'honda',
#  u'Zelas': u'toyota',
#  u'Zio': u'toyota',
#  u'a3': u'audi',
#  u'a4': u'audi',
#  u'a5': u'audi',
#  u'a6': u'audi',
#  u'a7': u'audi',
#  u'a8': u'audi',
#  u'accord': u'honda',
#  u'accords': u'honda',
#  u'agile': u'chevrolet',
#  u'alpina': u'bmw',
#  u'altima': u'nissan',
#  u'altimas': u'nissan',
#  u'armada': u'nissan',
#  u'aura': u'saturn',
#  u'avalon': u'toyota',
#  u'avenger': u'dodge',
#  u'aveo': u'chevrolet',
#  u'azera': u'hyundai',
#  u'aztek': u'pontiac',
#  u'bB': u'toyota',
#  u'beetle': u'volkswagen',
#  u'benz': u'mercedes',
#  u'bmwesque': u'bmw',
#  u'bmws': u'bmw',
#  u'buicks': u'buick',
#  u'c-class': u'mercedes',
#  u'c-max': u'ford',
#  u'c70': u'volvo',
#  u'cadenza': u'kia',
#  u'caliber': u'dodge',
#  u'camaro': u'chevrolet',
#  u'camry': u'toyota',
#  u'camrybest': u'toyata',
#  u'camrys': u'toyota',
#  u'caprice': u'chevrolet',
#  u'captiva': u'chevrolet',
#  u'cavalier': u'chevrolet',
#  u'century': u'buick',
#  u'challenger': u'dodge',
#  u'charger': u'dodge',
#  u'chevy': u'chevrolet',
#  u'chrysler 200': u'chrysler',
#  u'chrysler 300': u'chrysler',
#  u'chryslers': u'chrysler',
#  u'cl-class': u'mercedes',
#  u'cmax': u'ford',
#  u'cobalt': u'chevrolet',
#  u'corolla': u'toyota',
#  u'corvette': u'chevrolet',
#  u'crosstour': u'honda',
#  u'crosstrek': u'subaru',
#  u'cruiser': u'chrysler',
#  u'cruze': u'chevrolet',
#  u'crv': u'honda',
#  u'cube': u'nissan',
#  u'cultus': u'suzuki',
#  u'cx5': u'mazda',
#  u'cx9': u'mazda',
#  u'dart': u'dodge',
#  u'durango': u'dodge',
#  u'e-class': u'mercedes',
#  u'ecoline': u'ford',
#  u'enclave': u'buick',
#  u'encore': u'buick',
#  u'eos': u'volkswagen',
#  u'equinox': u'chevrolet',
#  u'escalade': u'cadillac',
#  u'escape': u'ford',
#  u'escudo': u'suzuki',
#  u'everest': u'ford',
#  u'ex-l': u'honda',
#  u'exl': u'honda',
#  u'expedition': u'ford',
#  u'explorer': u'ford',
#  u'express': u'chevrolet',
#  u'f-150': u'ford',
#  u'f150': u'ford',
#  u'fords': u'ford',
#  u'forsa': u'suzuki',
#  u'forte': u'kia',
#  u'freestar': u'ford',
#  u'frontier': u'nissan',
#  u'fusionmilan': u'ford',
#  u'fusions': u'ford',
#  u'fx35': u'infiniti',
#  u'g25': u'infiniti',
#  u'g3': u'pontiac',
#  u'g37': u'infiniti',
#  u'g4': u'pontiac',
#  u'g5': u'pontiac',
#  u'g6': u'pontiac',
#  u'g8': u'pontiac',
#  u'galant': u'mitsubishi',
#  u'galaxy': u'ford',
#  u'geo metro': u'suzuki',
#  u'golf': u'volkswagen',
#  u'grand am': u'pontiac',
#  u'grand prix': u'pontiac',
#  u'grand wagon': u'subaru',
#  u'gravel': u'subaru',
#  u'gti': u'volkswagen',
#  u'gto': u'pontiac',
#  u'gxp': u'pontiac',
#  u'highlander': u'toyota',
#  u'hondas': u'honda',
#  u'hyundaikia': u'hyndai kia',
#  u'hyundais': u'hyundai',
#  u'i10': u'hyundai',
#  u'i20': u'hyundai',
#  u'i30': u'hyundai',
#  u'i40': u'hyundai',
#  u'i45': u'hyundai',
#  u'iQ': u'toyota',
#  u'impala': u'chevrolet',
#  u'integra': u'acura',
#  u'intrepid': u'dodge',
#  u'ist': u'toyota',
#  u'ix20': u'hyundai',
#  u'jetta': u'volkswagen',
#  u'journey': u'dodge',
#  u'juke': u'nissan',
#  u'k900': u'kia',
#  u'kias': u'kia',
#  u'koup': u'kia',
#  u'kuga': u'ford',
#  u'la crosse': u'buick',
#  u'lacrosse': u'buick',
#  u'lancaster': u'subaru',
#  u'lancer': u'mitsubishi',
#  u'leaf': u'nissan',
#  u'liana': u'suzuki',
#  u'liberty': u'subaru',
#  u'lumina': u'chevrolet',
#  u'lx': u'chrysler',
#  u'magnum': u'dodge',
#  u'malibu': u'chevrolet',
#  u'malibus': u'chevrolet',
#  u'maxima': u'nissan',
#  u'mazda6i': u'mazda',
#  u'mazda6s': u'mazda',
#  u'mazdas': u'mazda',
#  u'mercedes': u'mercedes-benz',
#  u'mercedes-benz': u'mercedes',
#  u'mercedesbenz': u'mercedes',
#  u'mercury': u'mercury',
#  u'milan': u'mercury',
#  u'mkc': u'lincoln',
#  u'mks': u'lincoln',
#  u'mkt': u'lincoln',
#  u'mkx': u'lincoln',
#  u'mkz': u'lincoln',
#  u'murano': u'nissan',
#  u'mustang': u'ford',
#  u'navigator': u'lincoln',
#  u'nbox': u'honda',
#  u'nissans': u'nissan',
#  u'odessey': u'honda',
#  u'optima': u'kia.',
#  u'pacifica': u'chrysler',
#  u'park avenue': u'buick',
#  u'passat': u'volkwagen',
#  u'passats': u'volkswagen',
#  u'pathfinder': u'nissan',
#  u'pilot': u'honda',
#  u'prius': u'toyota',
#  u'q3': u'audi',
#  u'q5': u'audi',
#  u'q50': u'infiniti',
#  u'q60': u'infiniti',
#  u'q7': u'audi',
#  u'q70': u'infiniti',
#  u'quattro': u'audi',
#  u'quest,': u'nissan.',
#  u'quest.': u'nissan.',
#  u'qx50': u'infiniti',
#  u'qx60': u'infiniti',
#  u'qx70': u'infiniti',
#  u'rabbit': u'volkswagen',
#  u'ram': u'dodge',
#  u'regal': u'buick',
#  u'rlx': u'acura',
#  u'rogue': u'nissan',
#  u'rx-8': u'mazda',
#  u'rx8': u'mazda',
#  u's-class': u'mercedes',
#  u's-max': u'ford',
#  u's60': u'volvo',
#  u's80': u'volvo',
#  u'santa': u'hyundai',
#  u'sebring': u'chrysler',
#  u'sedona': u'kia',
#  u'sentra': u'nissan',
#  u'solara': u'toyota',
#  u'sonatas': u'hyundai',
#  u'sonic': u'chevrolet',
#  u'sorento': u'kia',
#  u'spark': u'chevrolet',
#  u'sportwagen': u'volkswagen',
#  u'srx': u'cadillac',
#  u'stealth': u'dodge',
#  u'suburban': u'chevrolet',
#  u'sunfire': u'pontiac',
#  u'supervan': u'ford',
#  u'tavera': u'chevrolet',
#  u'tiguan': u'volkswagen',
#  u'titan': u'nissan',
#  u'touraeg': u'volkswagen',
#  u'town and country': u'chrysler',
#  u'town car': u'lincoln',
#  u'toyotas': u'toyota',
#  u'trailblazer': u'chevrolet',
#  u'tribeca': u'subaru',
#  u'v60': u'volvo',
#  u'venza': u'toyota',
#  u'veracruz': u'hyundai',
#  u'versa': u'nissan',
#  u'vibe': u'pontiac',
#  u'vigor': u'acura',
#  u'viper': u'dodge',
#  u'volkwagen': u'volkswagen',
#  u'volt': u'chevrolet',
#  u'vw': u'volkswagen',
#  u'vws': u'volkswagen',
#  u'wrx': u'subaru',
#  u'xc60': u'volvo',
#  u'xc70': u'volvo',
#  u'xc90': u'volvo',
#  u'xdrive': u'bmw',
#  u'xg': u'hyundai',
#  u'xterra': u'nissan',
#  u'xts': u'cadillac',
#  u'zephyr': u'lincoln'}

# %%
import math

def count_brand_frequencies(posts, brand_dict):
    
    ''' Take list of posts and return a dictionary of frequency counts for each brand that was mentioned '''
    
    # Initialize frequency dictionary
    brand_counts = {}
    
    # Iterate through posts
    for post in posts:
        
        post = post.decode("utf8")
        
        # Retrieve brand names and models from post
        targets = get_targets(post, brand_dict)
        
        # Create list of brands that were mentioned in post (models converted to respective brands)
        brands = models_to_brands(targets, brand_dict)
        
        # Retrieve only unique brand names from list of brands that were mentioned
        unique_brands = get_unique_brands(brands)
        
        # Add each brand that was mentioned to total brand count
        for brand in unique_brands:
            if brand not in brand_counts.keys():
                brand_counts[brand] = 1
            else:
                brand_counts[brand] += 1
    
    return brand_counts

# %%
# Run on sample
count_brand_frequencies(test, brand_dict)
# Out:
# {u'acura': 13,
#  u'audi': 29,
#  u'bmw': 26,
#  u'buick': 1,
#  u'cadillac': 4,
#  u'chevrolet': 2,
#  u'chrysler': 2,
#  u'ford': 11,
#  u'honda': 8,
#  u'hyundai': 1,
#  u'infiniti': 10,
#  u'lincoln': 4,
#  u'mazda': 2,
#  u'mercedes': 11,
#  u'mercedes-benz': 5,
#  u'mitsubishi': 2,
#  u'nissan': 7,
#  u'pontiac': 1,
#  u'subaru': 2,
#  u'suzuki': 2,
#  u'toyota': 6,
#  u'volkswagen': 8,
#  u'volkwagen': 5,
#  u'volvo': 8}

# %%
# Run on entire set of posts
brand_frequencies = count_brand_frequencies(posts, brand_dict)
brand_frequencies
# Out:
# {u'acura': 665,
#  u'audi': 776,
#  u'bmw': 2669,
#  u'buick': 82,
#  u'cadillac': 265,
#  u'chevrolet': 166,
#  u'chrysler': 88,
#  u'dodge': 102,
#  u'ford': 218,
#  u'honda': 515,
#  u'hyundai': 117,
#  u'infiniti': 597,
#  u'kia': 34,
#  u'lincoln': 215,
#  u'mazda': 135,
#  u'mercedes': 194,
#  u'mercedes-benz': 245,
#  u'mercury': 11,
#  u'mitsubishi': 41,
#  u'nissan': 387,
#  u'pontiac': 91,
#  u'saturn': 24,
#  u'subaru': 190,
#  u'suzuki': 13,
#  u'toyota': 402,
#  u'volkswagen': 259,
#  u'volkwagen': 77,
#  u'volvo': 290}

# %%
df_brand_frequencies = pd.DataFrame(brand_frequencies.items(), columns=['brand','frequency'])
df_brand_frequencies = df_brand_frequencies.sort_values(by='frequency', ascending=False).reset_index().drop('index', axis=1)
df_brand_frequencies
# Out:
#             brand  frequency
# 0             bmw       2669
# 1            audi        776
# 2           acura        665
# 3        infiniti        597
# 4           honda        515
# 5          toyota        402
# 6          nissan        387
# 7           volvo        290
# 8        cadillac        265
# 9      volkswagen        259
# 10  mercedes-benz        245
# 11           ford        218
# 12        lincoln        215
# 13       mercedes        194
# 14         subaru        190
# 15      chevrolet        166
# 16          mazda        135
# 17        hyundai        117
# 18          dodge        102
# 19        pontiac         91
# 20       chrysler         88
# 21          buick         82
# 22      volkwagen         77
# 23     mitsubishi         41
# 24            kia         34
# 25         saturn         24
# 26         suzuki         13
# 27        mercury         11

# %%
# %pylab inline
bar(df_brand_frequencies.index, df_brand_frequencies['frequency'])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
# <Container object of 28 artists>

# %% [markdown]
# ### Start of Part C
# - Does reference code from above
# - Some new functions created that are slightly different from above

# %%
from nltk.corpus import stopwords
import string

def get_attribute_targets(post, brand_dict):
    
    ''' Take individual post and return only the words that are not brand/model and not stopwords '''
    
    punctuations = list(string.punctuation)
    
    # Tokenize post    
    tokens = word_tokenize(post)
    
    # Remove stop words and punctuation
    targets = [word.lower() for word in tokens if word.lower() not in stopwords.words('english') and word.lower() not in ["cars","car", "like","one","would"]]
    #targets_punct = [word.lower() for word in targets if word.lower() not in punctuations] 
    targets_punct = [word.lower() for word in targets if word.lower().isalpha()] 
    
    # Remove brands and models
    targets_final = [word.lower() for word in targets_punct if word.lower() not in brand_dict.keys() and word.lower() not in brand_dict.values()]
    
    return targets_final

# %%
def words_to_attributes(targets, attribute_dict):
    ''' Take list of tokenized words and return a list with targets replaced with attributes'''
    
    # Create a list of tokens converted to attributes
    tokens = []
    
    # Iterate through words
    for word in targets:
        
        # Convert words to attributes and add to tokens list
        if word in attribute_dict.keys():
            tokens.append(attribute_dict[word])
        
        # Add all other words un-converted
        else:
            tokens.append(word)
    
    return tokens

# %%
def count_attribute_frequencies(posts, brand_dict, attribute_dict):
    ''' Take list of posts and return a dictionary of frequency counts for each non-brand that was mentioned '''
    
    # Initialize frequency dictionary
    word_counts = {}
    
    # Iterate through posts
    for post in posts:
        
        post = post.decode("utf8")
        
        # Retrieve attribute tokens from post
        targets = get_attribute_targets(post, brand_dict)
        
        # Create list of attributes (converted rom list), continue if none provided
        if len(attribute_dict.keys())>0:
            attributes = words_to_attributes(targets, attribute_dict)
        else:
            attributes = targets
        
        # Retrieve only unique tokens from list that were mentioned
        unique_tokens = get_unique_brands(attributes)
        
        # Add each token that was mentioned to total token count
        for token in unique_tokens:
            if token not in word_counts.keys():
                word_counts[token] = 1
            else:
                word_counts[token] += 1
                
    return word_counts

# %% [markdown]
# ### Excluded code which first calculated the frequencies of all words
# - Manually "mapped" some words to categories and created AttributesMap
# - Unecessary extra computing, so excluded
# <br>NE

# %%
attributes = pd.read_csv('AttributesMap.csv')

words = attributes['word']
categories = attributes['category']

# Convert words and category strings to unicode
keys = []
values = []
for word in words:
    keys.append(unicode(word, "ISO-8859-1"))

for cat in categories:
    values.append(unicode(cat, "ISO-8859-1"))

# Create dictionary mapping words to their respective categories
attribute_dict = dict(zip(keys, values))

# %%
# Map words to categories and count frequencies
attribute_frequencies_convert = count_attribute_frequencies(posts, brand_dict, attribute_dict)
attribute_frequencies_convert

# %%
# Create dataframe
df_attribute_frequencies_convert = pd.DataFrame(attribute_frequencies_convert.items(), columns=['attribute','frequency'])

# Sort by frequency
df_attribute_frequencies_convert = df_attribute_frequencies_convert.sort_values(by='frequency', ascending=False).reset_index().drop('index', axis=1)

# Select top 5 most frequent
attribute_top_5 = df_attribute_frequencies_convert.ix[:4]['attribute']
attribute_top_5

# %% [markdown]
# ### Top 5 have been exported to a text file "attribute5.txt"
# - format is word1,word2,word3,word4,word5,
